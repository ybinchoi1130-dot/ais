# %%
import sys
print("파이썬 버전:", sys.version)
# Out:
# 파이썬 버전: 3.13.14 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:41) [MSC v.1942 64 bit (AMD64)]

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
print("안녕 파이썬!!!")
# Out:
# 안녕 파이썬!!!
